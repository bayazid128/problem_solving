# %% [markdown]
# ![image_2023-07-22_155652164.png](data:image/png;base64,...)

# %%
def Remove_Exclamation_Marks(str):
  return str.replace('!','')

print (Remove_Exclamation_Marks(input("Enter sentence: ")))
# Out:
# Enter sentence: Hello! World!
# Hello World

# %% [markdown]
# ![image_2023-07-22_155805154.png](data:image/png;base64,...)

# %%
ls= [-52, 56, 30, 29, -54, 0, -110]
def largest_num(ls):
  return max(ls)
def lowest_num(ls):
  return min(ls)
print ("max = {}, min = {}".format(largest_num(ls),lowest_num(ls)))
# Out:
# max = 56, min = -110

# %% [markdown]
# ![image_2023-07-22_155927452.png](data:image/png;base64,...)

# %%
def litres(time):
  return "litres = {}".format(int(time *.5))

print(litres(float(input("Time in hours: "))))
# Out:
# Time in hours: 11.8
# litres = 5
