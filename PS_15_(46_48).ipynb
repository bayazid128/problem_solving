# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
def sum_of_differences(arr):
    return max(arr) - min(arr) if arr else 0

print(sum_of_differences([2,1,10]))
# Out:
# 9

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
def goals(arr):
  return sum(arr)

print(goals((5,10,2)))
print(goals((10,20,30)))
# Out:
# 17
# 60

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
def get_planet_name(id):
  return {1:'Mercury',2:'Venus',3:'Earth',4:'Mars',5:'Jupiter',6:'Saturn ',7:'Uranus',8:'Neptune'}.get(id,None)

print(get_planet_name(int(input('Planet id: '))))
# Out:
# Planet id: 5
# Jupiter
