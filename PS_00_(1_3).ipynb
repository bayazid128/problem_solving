# %% [markdown]
# ![image_2023-07-22_154501140.png](data:image/png;base64,...)

# %%
num= float(input("Enter number: "))
def kata(num):
  return num*8 if num%2==0 else num*9
print (kata(num))
# Out:
# Enter number: 5
# 45.0

# %% [markdown]
# ![image_2023-07-22_154537291.png](data:image/png;base64,...)

# %%
year= float(input("Enter a year: "))
import math
def century(year):
  return math.ceil(year / 100)
print(century(year))
# Out:
# Enter a year: 101
# 2

# %% [markdown]
# ![image_2023-07-22_154714301.png](data:image/png;base64,...)

# %%
def is_divisble(n,x,y):
  return True if (n%x==0) and (n%y==0) else False
print(is_divisble(10,3,5))
# Out:
# False
