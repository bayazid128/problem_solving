# %% [markdown]
# 67)
#
# ![image.png](data:image/png;base64,...)

# %%
def positive_sum(arr):
  return sum(i for i in arr if i>-1)

print(positive_sum([]))
print(positive_sum([1,-4,7,12]))
# Out:
# 0
# 20

# %% [markdown]
# 68)
#
# ![image.png](data:image/png;base64,...)

# %%
def get_volume_of_cuboid(l, w, h):
  return l*w*h

print(get_volume_of_cuboid(5,5,5))
# Out:
# 125

# %% [markdown]
# 69)
#
# ![image.png](data:image/png;base64,...)

# %%
def get_average(marks):
  return int(sum(marks)/len(marks))

print(get_average([5,3,2]))
# Out:
# 3
