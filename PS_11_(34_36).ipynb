# %% [markdown]
# ![pic.PNG](data:image/png;base64,...)

# %%
def correct(text):
  return text.replace('5','S').replace('0','O').replace('1','I')

print(correct(input("Enter text: ")))
# Out:
# Enter text: HELL0, 1 AM 5EVEN YEAR5 0LD.
# HELLO, I AM SEVEN YEARS OLD.

# %% [markdown]
# ![pic.PNG](data:image/png;base64,...)

# %%
def greet(name):
  return 'Hello! How are you today, my love?' if name=='Johnny' else ('Hello! How are you today {}?'.format(name))

print(greet('Johnny'))
print(greet(input("Enter your name: ")))
# Out:
# Hello! How are you today, my love?
# Enter your name: john
# Hello! How are you today john?

# %% [markdown]
# ![Capture.PNG](data:image/png;base64,...)

# %%
def multiply(a, b):
  return a * b

print(multiply(float(input("First Number:")),float(input("Second Number:"))))
# Out:
# First Number:9.9
# Second Number:8.8
# 87.12
