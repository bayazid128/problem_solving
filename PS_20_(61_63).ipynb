# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
def two_sort(ls):
  ["apple", "Banana", "cherry", "Date", "grape"]
  return '***'.join(min(ls))

print(two_sort(["apple", "Banana", "cherry", "Date", "grape"]))
# Out:
# B***a***n***a***n***a

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
def reverseseq(n):
  array= [i for i in range(n,0,-1)]
  return array

print(reverseseq(5))
# Out:
# [5, 4, 3, 2, 1]

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
def set_alarm(employed,vacation):
    return employed==True and vacation==False

print(set_alarm(True,True))
print(set_alarm(True,False))
print(set_alarm(False,True))
print(set_alarm(False,False))
# Out:
# False
# True
# False
# False
