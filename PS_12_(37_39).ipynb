# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
def get_char(num):
  return chr(num)

print(get_char(int(input("Number: "))))
# Out:
# Number: 100
# d

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
def nth_even(n):
  n= int(input("Enter Number: "))
  return 'The({})th even number is {}'.format(n,2*(n-1)) if n!=0 else None

print(nth_even('n'))
# Out:
# Enter Number: 1298734
# The(1298734)th even number is 2597466

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
def between(a,b):
  return list(i for i in range(a+b) if (i>=a) and (i<=b))

print(between(int(input('Enter the first number: ')),int(input('Enter the second number: '))))
# Out:
# Enter the first number: 1
# Enter the second number: 4
# [1, 2, 3, 4]
