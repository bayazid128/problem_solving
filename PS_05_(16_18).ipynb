# %% [markdown]
# ![image_2023-07-22_160237423.png](data:image/png;base64,...)

# %%
def repeat_str(s,n):
  return s*n

print(repeat_str(input("Enter a string: "),int(input("repeat: "))))
# Out:
# Enter a string: Hello
# repeat: 5
# HelloHelloHelloHelloHello

# %% [markdown]
# ![image_2023-07-22_160323169.png](data:image/png;base64,...)

# %%
def del_spaces(str):
  return str.replace(' ','')

print(del_spaces(input("Enter a string: ")))
# Out:
# Enter a string: Hello World ! 1 2 3 4 5
# HelloWorld!12345

# %% [markdown]
# ![image_2023-07-22_160407494.png](data:image/png;base64,...)

# %%
def str_count(str,letter):
  return str.count(letter)

print(str_count("amazing","a"))
print(str_count("amazing","z"))
print(str_count("amazing","e"))
# Out:
# 2
# 1
# 0
